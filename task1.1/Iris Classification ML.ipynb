# %% [markdown]
# # LetsGrowMore #january 2022
#
# Author : Neha Anil Survase
#
# Task1 : 1)Iris Flowers Classification
#
# Level : Beginner
#
# Language : Python
#
# Software : google collab

# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Reading the Dataset

# %%
ifc = pd.read_csv('iris.csv')
ifc
# Out:
#      Sepal_length   Sepal_width  Petal_length  Petal_width         Species
# 0              5.1          3.5           1.4          0.2     Iris-setosa
# 1              4.9          3.0           1.4          0.2     Iris-setosa
# 2              4.7          3.2           1.3          0.2     Iris-setosa
# 3              4.6          3.1           1.5          0.2     Iris-setosa
# 4              5.0          3.6           1.4          0.2     Iris-setosa
# ..             ...          ...           ...          ...             ...
# 145            6.7          3.0           5.2          2.3  Iris-virginica
# 146            6.3          2.5           5.0          1.9  Iris-virginica
# 147            6.5          3.0           5.2          2.0  Iris-virginica
# 148            6.2          3.4           5.4          2.3  Iris-virginica
# 149            5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
ifc.head() # Shows the first five rows of the data
# Out:
#    Sepal_length   Sepal_width  Petal_length  Petal_width      Species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa

# %%
ifc.tail() # Shows the last five rows of the data
# Out:
#      Sepal_length   Sepal_width  Petal_length  Petal_width         Species
# 145            6.7          3.0           5.2          2.3  Iris-virginica
# 146            6.3          2.5           5.0          1.9  Iris-virginica
# 147            6.5          3.0           5.2          2.0  Iris-virginica
# 148            6.2          3.4           5.4          2.3  Iris-virginica
# 149            5.9          3.0           5.1          1.8  Iris-virginica

# %%
ifc['Species'].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
ifc.isnull().sum() # Checks whether the dataset contains any null value or not
# Out:
# Sepal_length     0
# Sepal_width      0
# Petal_length     0
# Petal_width      0
# Species          0
# dtype: int64

# %%
ifc.describe() 
# Gives the Statistical information like Count, Mean, Standard deviation, Minimum value, Maximum value, Quartile
# Out:
#        Sepal_length   Sepal_width  Petal_length  Petal_width
# count     150.000000   150.000000    150.000000   150.000000
# mean        5.843333     3.054000      3.758667     1.198667
# std         0.828066     0.433594      1.764420     0.763161
# min         4.300000     2.000000      1.000000     0.100000
# 25%         5.100000     2.800000      1.600000     0.300000
# 50%         5.800000     3.000000      4.350000     1.300000
# 75%         6.400000     3.300000      5.100000     1.800000
# max         7.900000     4.400000      6.900000     2.500000

# %%
ifc.info() # Print the summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sepal_length   150 non-null    float64
#  1   Sepal_width    150 non-null    float64
#  2   Petal_length   150 non-null    float64
#  3   Petal_width    150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
ifc.count()
# Out:
# Sepal_length     150
# Sepal_width      150
# Petal_length     150
# Petal_width      150
# Species          150
# dtype: int64

# %% [markdown]
# ## Data Visualization and Correlation Matrix

# %%
sns.pairplot(ifc)

# %%
sns.pairplot(ifc,hue='Species')
# blue color represents the setosa
# orange color represents the versicolor
# green color represeents the virginica

# %%
sns.countplot(x='Species', data=ifc, )
plt.show() # Shows the relationship between the sepal length and sepal width and also between Petal leangth and Petal width

# %%
ifc.corr()
# Out:
#                Sepal_length   Sepal_width  Petal_length  Petal_width
# Sepal_length        1.000000    -0.109369      0.871754     0.817954
# Sepal_width        -0.109369     1.000000     -0.420516    -0.356544
# Petal_length        0.871754    -0.420516      1.000000     0.962757
# Petal_width         0.817954    -0.356544      0.962757     1.000000

# %%
corr=ifc.corr()
fig,ax=plt.subplots(figsize=(5,5))
sns.heatmap(corr, annot=True, ax=ax)

# %%
lbec=LabelEncoder()

# %%
ifc['Species']=lbec.fit_transform(ifc['Species'])

# %%
ifc.head()
# Out:
#    Sepal_length   Sepal_width  Petal_length  Petal_width  Species
# 0            5.1          3.5           1.4          0.2        0
# 1            4.9          3.0           1.4          0.2        0
# 2            4.7          3.2           1.3          0.2        0
# 3            4.6          3.1           1.5          0.2        0
# 4            5.0          3.6           1.4          0.2        0

# %% [markdown]
# ## Splitting the data into testing and training datasets

# %%
X=ifc.drop(columns=['Species'])
Y=ifc['Species']
x_train,x_test,y_train,y_test=train_test_split(X,Y)

# %% [markdown]
# ## Checking the Accuracy by using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print(model.score(x_test,y_test))
